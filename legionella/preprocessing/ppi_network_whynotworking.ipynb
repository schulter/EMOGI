# %% [markdown]
# # Why some genes have differential expression but are not in PPI network?

# %%
import numpy as np
import pandas as pd
import h5py

# %%
def load_diff_expr(file_name_up, file_name_down):
    """Loads differential up and down-regulated genes."""
    differential_expression_up = pd.read_html(file_name_up,
                                           index_col=2,
                                           header=0
                                          )[0]
    differential_expression_down = pd.read_html(file_name_down,
                                               index_col=2,
                                               header=0
                                               )[0]
    print ("Loaded Differential Expression from html...")

    # concatenate the up and down-regulated genes
    differential_expression_down.drop('Ensembl', inplace=True)
    differential_expression_down = differential_expression_down.convert_objects(convert_numeric=True)
    de = pd.concat([differential_expression_up, differential_expression_down])
    return de

# %%
# load network
with h5py.File('../data/preprocessing/ppi_networks.h5', 'r') as f:
    gene_expression_data = f['gene_expression'][:]
    ppi_network = f['consensusPathDB_ppi'][:]
    gene_names = f['gene_names'][:]

de = load_diff_expr('../data/differential_expression/DEanalysis/gpp1605-up.html',
                    '../data/differential_expression/DEanalysis/gpp1605-down.html'
                   )
gene_names_df = pd.DataFrame(gene_names, columns=['Ensembl', 'Gene-name'])
gene_names_df = gene_names_df.set_index('Ensembl')
# Out:
# Loaded Differential Expression from html...
# /pkg/python-3.6.0-0/lib/python3.6/site-packages/ipykernel/__main__.py:15: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
common = de.join(gene_names_df, lsuffix='left', how='inner')

# %%
gene_names_df[~de.isin(gene_names_df)].dropna()
# Out:
# Empty DataFrame
# Columns: [Gene-name]
# Index: []

# %%
n = gene_names[:,0]
'ENSG00000000457' in n
# Out:
# True

# %%
'ENSG00000000457' in de.index
# Out:
# False

# %%
common.shape
# Out:
# (4754, 9)

# %%
gene_names_df.shape[0] - common.shape[0]
# Out:
# 5613

# %%
gene_names_df[gene_names_df['Gene-name'] == 'SCYL3']
# Out:
#                 Gene-name
# Ensembl
# ENSG00000000457     SCYL3

# %%
de[de['Gene-name'] == 'SCYL3']
# Out:
# Empty DataFrame
# Columns: [Gene-type, Gene-name, baseMean, log2FoldChange, lfcSE, stat, pvalue, padj]
# Index: []

# %%
gene_names_df['Gene-name'].unique().shape
# Out:
# (10355,)

# %%
gene_names_df.shape
# Out:
# (10367, 1)

# %%
de['Gene-name'].unique().shape
# Out:
# (8856,)

# %%
gene_names_df[de.isin(gene_names_df)].dropna().shape
# Out:
# (4754, 1)

# %%
de.isin(gene_names_df)
# Out:
#                 Gene-type Gene-name baseMean log2FoldChange  lfcSE   stat  \
# Ensembl
# ENSG00000140403     False      True    False          False  False  False
# ENSG00000132002     False      True    False          False  False  False
# ENSG00000162616     False      True    False          False  False  False
# ENSG00000120694     False      True    False          False  False  False
# ENSG00000149257     False      True    False          False  False  False
# ENSG00000178381     False      True    False          False  False  False
# ENSG00000110172     False     False    False          False  False  False
# ENSG00000151929     False      True    False          False  False  False
# ENSG00000168685     False      True    False          False  False  False
# ENSG00000109846     False      True    False          False  False  False
# ENSG00000204388     False      True    False          False  False  False
# ENSG00000162783     False     False    False          False  False  False
# ENSG00000204389     False      True    False          False  False  False
# ENSG00000164070     False      True    False          False  False  False
# ENSG00000100591     False      True    False          False  False  False
# ENSG00000086061     False      True    False          False  False  False
# ENSG00000160570     False      True    False          False  False  False
# ENSG00000004478     False      True    False          False  False  False
# ENSG00000215861     False     False    False          False  False  False
# ENSG00000280385     False     False    False          False  False  False
# ENSG00000114416     False      True    False          False  False  False
# ENSG00000168439     False      True    False          False  False  False
# ENSG00000013441     False      True    False          False  False  False
# ENSG00000105993     False      True    False          False  False  False
# ENSG00000204390     False      True    False          False  False  False
# ENSG00000275131     False     False    False          False  False  False
# ENSG00000184378     False     False    False          False  False  False
# ENSG00000163376     False     False    False          False  False  False
# ENSG00000263606     False     False    False          False  False  False
# ENSG00000184205     False      True    False          False  False  False
# ...                   ...       ...      ...            ...    ...    ...
# ENSG00000106404     False      True    False          False  False  False
# ENSG00000077514     False      True    False          False  False  False
# ENSG00000128311     False      True    False          False  False  False
# ENSG00000168765     False      True    False          False  False  False
# ENSG00000197815     False     False    False          False  False  False
# ENSG00000150456     False     False    False          False  False  False
# ENSG00000135476     False      True    False          False  False  False
# ENSG00000080293     False     False    False          False  False  False
# ENSG00000090382     False      True    False          False  False  False
# ENSG00000149635     False     False    False          False  False  False
# ENSG00000160185     False     False    False          False  False  False
# ENSG00000164400     False     False    False          False  False  False
# ENSG00000189139     False     False    False          False  False  False
# ENSG00000200156     False     False    False          False  False  False
# ENSG00000201277     False     False    False          False  False  False
# ENSG00000202407     False     False    False          False  False  False
# ENSG00000207263     False     False    False          False  False  False
# ENSG00000223262     False     False    False          False  False  False
# ENSG00000223628     False     False    False          False  False  False
# ENSG00000223784     False     False    False          False  False  False
# ENSG00000227397     False     False    False          False  False  False
# ENSG00000227712     False     False    False          False  False  False
# ENSG00000233646     False     False    False          False  False  False
# ENSG00000240647     False     False    False          False  False  False
# ENSG00000249345     False     False    False          False  False  False
# ENSG00000264026     False     False    False          False  False  False
# ENSG00000272123     False     False    False          False  False  False
# ENSG00000274978     False     False    False          False  False  False
# ENSG00000279064     False     False    False          False  False  False
# ENSG00000279615     False     False    False          False  False  False
#
#                 pvalue   padj
# Ensembl
# ENSG00000140403  False  False
# ENSG00000132002  False  False
# ENSG00000162616  False  False
# ENSG00000120694  False  False
# ENSG00000149257  False  False
# ENSG00000178381  False  False
# ENSG00000110172  False  False
# ENSG00000151929  False  False
# ENSG00000168685  False  False
# ENSG00000109846  False  False
# ENSG00000204388  False  False
# ENSG00000162783  False  False
# ENSG00000204389  False  False
# ENSG00000164070  False  False
# ENSG00000100591  False  False
# ENSG00000086061  False  False
# ENSG00000160570  False  False
# ENSG00000004478  False  False
# ENSG00000215861  False  False
# ENSG00000280385  False  False
# ENSG00000114416  False  False
# ENSG00000168439  False  False
# ENSG00000013441  False  False
# ENSG00000105993  False  False
# ENSG00000204390  False  False
# ENSG00000275131  False  False
# ENSG00000184378  False  False
# ENSG00000163376  False  False
# ENSG00000263606  False  False
# ENSG00000184205  False  False
# ...                ...    ...
# ENSG00000106404  False  False
# ENSG00000077514  False  False
# ENSG00000128311  False  False
# ENSG00000168765  False  False
# ENSG00000197815  False  False
# ENSG00000150456  False  False
# ENSG00000135476  False  False
# ENSG00000080293  False  False
# ENSG00000090382  False  False
# ENSG00000149635  False  False
# ENSG00000160185  False  False
# ENSG00000164400  False  False
# ENSG00000189139  False  False
# ENSG00000200156  False  False
# ENSG00000201277  False  False
# ENSG00000202407  False  False
# ENSG00000207263  False  False
# ENSG00000223262  False  False
# ENSG00000223628  False  False
# ENSG00000223784  False  False
# ENSG00000227397  False  False
# ENSG00000227712  False  False
# ENSG00000233646  False  False
# ENSG00000240647  False  False
# ENSG00000249345  False  False
# ENSG00000264026  False  False
# ENSG00000272123  False  False
# ENSG00000274978  False  False
# ENSG00000279064  False  False
# ENSG00000279615  False  False
#
# [8877 rows x 8 columns]

# %%
gene_names_df.join(de, how='inner', lsuffix='_l').shape
# Out:
# (4754, 9)
